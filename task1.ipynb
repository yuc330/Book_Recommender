# %%
import pandas as pd
import numpy as np
from scipy.io import arff
from io import StringIO
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import balanced_accuracy_score
import random
from scipy.stats import pearsonr
from collections import defaultdict

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
data = pd.DataFrame.from_csv('train_Interactions.csv', sep = ',').reset_index()

# %%
train = data[:190000]
val = data[190000:]

# %%
val['read'] = 1

# %%
book_list = data['bookID'].unique()
read_list = data.groupby('userID')['bookID'].apply(list).to_dict()

# %%
neg_val = pd.DataFrame({'userID':val['userID'], 'bookID': val['userID'].apply(lambda x: random.choice(list(set(book_list) - set(read_list[x])))), 'read': 0})

# %%
new_val = pd.concat([val.drop('rating', axis = 1), neg_val])

# %%
bookCount = defaultdict(int)
totalRead = 0

for user,book,_ in np.array(data.values):
    bookCount[book] += 1
    totalRead += 1

mostPopular = [(bookCount[x], x) for x in bookCount]
mostPopular.sort()
mostPopular.reverse()
mostPopular
len(mostPopular)
# Out:
# 7170

# %%
### Would-read baseline: just rank which books are popular and which are not, and return '1' if a book is among the top-ranked
from collections import defaultdict
def predict_baseline(threshold):
    bookCount = defaultdict(int)
    totalRead = 0

    for user,book,_ in np.array(data.values):
        bookCount[book] += 1
        totalRead += 1

    mostPopular = [(bookCount[x], x) for x in bookCount]
    mostPopular.sort()
    mostPopular.reverse()

    return1 = set()
    count = 0
    for ic, i in mostPopular:
        count += ic
        return1.add(i)
        if count > totalRead*threshold/100: break

    predictions = []
    for user,book,_ in np.array(new_val.values):
        if book in return1:
            predictions.append(1)
        else:
            predictions.append(0)
    return predictions

# %%
print('prediction accuracy is:')
sum(predict_baseline(50) == new_val['read'])/len(new_val['read'])
# Out:
# prediction accuracy is:
# 0.65125

# %%
sum(predict_baseline(60) == new_val['read'])/len(new_val['read'])
# Out:
# 0.6589

# %%
read_train_list = train.groupby('userID')['bookID'].apply(list).to_dict()
user_train_list = train.groupby('bookID')['userID'].apply(list).to_dict()

# %%
def predict_jaccard(threshold):
    def max_jaccard(x):
        bks = read_train_list[x.userID]
        if x.bookID in list(train.bookID.values):
            U = set(user_train_list[x.bookID])
        else:
            U = set()
        jaccards = [0]
        for b in bks:
            U_p = set(user_train_list[b])
            j = len(U_p.intersection(U))/len(U_p.union(U))
            jaccards.append(j)
        return max(jaccards)
    j_vals = new_val.apply(max_jaccard, axis = 1)
    return j_vals

# %%
train_books = train.bookID.unique()

# %%
def predict_pearson(threshold):
    def max_pearson(x):
        user_rate = UBmat.loc[x.userID,:]
        if x.bookID not in train_books:
            return 0
        user_list = UBmat.index[UBmat[x.bookID]>0].tolist()
        pearson = [0]
        for u in user_list:
            u_behav = UBmat.loc[u,:]
            p = pearsonr(user_rate, u_behav)[0]
            pearson.append(p)
        return max(pearson)
    p_vals = new_val.apply(max_pearson, axis = 1)
    return p_vals

# %%
p_pred = predict_pearson(0.0015)

# %%
p_vals = p_pred

# %%
p_result = (p_pred > 0.061).astype(int)

# %%
sum(p_result == new_val.read)/len(p_result)
# Out:
# 0.6441

# %%
j_vals = predict_jaccard(0.01)
predictions_j = (j_vals > 0.01).astype(int)

# %%
read_train_list = train.groupby('userID')['bookID'].apply(list).to_dict()
user_train_list = train.groupby('bookID')['userID'].apply(list).to_dict()

# %%
new_val['booklist'] = new_val.groupby('userID')['bookID'].apply(list)

# %%
booklist = new_val.groupby('userID')['bookID'].apply(list)

# %%
read_train_list = data.groupby('userID')['bookID'].apply(list).to_dict()
user_train_list = data.groupby('bookID')['userID'].apply(list).to_dict()

# %%
def union_jaccard(x):
        bks = set(read_train_list[x.userID])
        if x.bookID in list(data.bookID.values):
            U = set(user_train_list[x.bookID])
        else:
            U = set()
        U_p = set()
        for b in bks:
            U_p = U_p.union(set(user_train_list[b]))
            
        return len(U_p.intersection(U))/len(U_p.union(U))

# %%
j_vals = test_df.apply(union_jaccard, axis = 1)

# %%
test_df['jaccard'] = j_vals

# %%
UBmat = data.set_index('userID').pivot(columns = 'bookID', values = 'rating').fillna(0)

# %%
def sum_pearson(x):
    user_rate = UBmat.loc[x.userID,:]
    if x.bookID not in data.bookID.values:
        return 0
    user_list = UBmat.index[UBmat[x.bookID]>0].tolist()
    pearson = [0]
    for u in user_list:
        u_behav = UBmat.loc[u,:]
        p = pearsonr(user_rate, u_behav)[0]
        pearson.append(p)
    return sum(pearson)

# %%
test_df['pearson'] = test_df.apply(sum_pearson, axis = 1)

# %%
test_df['pearson'] = test_df['pearson'].fillna(0)

# %%
test_df['pnorm'] = test_df['pearson'].apply(lambda x: (x-np.mean(test_df['pearson']))/test_df['pearson'].std())

# %%
test_df['jnorm'] = test_df['jaccard'].apply(lambda x: (x-np.mean(test_df['jaccard']))/test_df['jaccard'].std())

# %%
test_df['sum_norm'] = test_df['pnorm'] + test_df['jnorm']

# %%
len_list = test_df.groupby('userID').apply(len)

# %%
test_df['rank'] = test_df.groupby('userID')['sum_norm'].apply(lambda x: x.rank(method = 'first'))

# %%
def det_pred(x):
    length = len_list.loc[x.userID]#len(x)
    pred_list = [0]*(length//2) + [1]*(length//2)
    return pred_list[int(x['rank'])-1]

# %%
test_df.isna().sum()
# Out:
# userID      0
# bookID      0
# jaccard     0
# rank        0
# pred        0
# pearson     0
# pnorm       0
# jnorm       0
# sum_norm    0
# dtype: int64

# %%
test_df['pred'] = test_df.apply(det_pred, axis = 1)

# %%
test_df
# Out:
#           userID     bookID   jaccard  rank  pred   pearson     pnorm  \
# 0      u65407115  b69897799  0.000000   1.0     0 -0.049593 -0.742242
# 1      u53740605  b39436893  0.002604   1.0     0  0.001530 -0.557184
# 2      u88031275  b83889575  0.000000   1.0     0 -0.061727 -0.786165
# 3      u99759913  b39270822  0.014599   4.0     1  0.379083  0.809500
# 4      u20090895  b47380623  0.012346   6.0     1  0.421032  0.961348
# 5      u24294545  b66431497  0.006438   1.0     0  0.122132 -0.120625
# 6      u55512157  b82932751  0.001419   1.0     0  0.040601 -0.415754
# 7      u49944817  b08859581  0.002635   2.0     0  0.098241 -0.207106
# 8      u25738103  b40864764  0.000000   1.0     0 -0.009422 -0.596829
# 9      u60899187  b27621138  0.004545   2.0     1  0.102473 -0.191788
# 10     u02807468  b95188078  0.002070   2.0     1 -0.050443 -0.745318
# 19993  u67964245  b97132208  0.001729   1.0     0 -0.009828 -0.598300
# 19994  u71745968  b96191053  0.000492   1.0     0  0.014772 -0.509253
# 19995  u14735314  b54613892  0.002716   1.0     0  0.088446 -0.242562
# 19996  u00713548  b10036624  0.010093  10.0     1  0.199942  0.161038
# 19997  u53512754  b57070326  0.000000   1.0     0 -0.045663 -0.728018
# 19998  u40683372  b06314002  0.000000   1.0     0 -0.013255 -0.610705
# 19999  u11383735  b57480183  0.002009   2.0     0 -0.017245 -0.625149
#
#           jnorm  sum_norm
# 0     -0.878833 -1.621076
# 1     -0.394511 -0.951695
# 2     -0.878833 -1.664998
# 3      1.836198  2.645699
# 4      1.417212  2.378560
# 5      0.318461  0.197836
# 6     -0.614845 -1.030599
# 7     -0.388768 -0.595874
# 8     -0.878833 -1.475663
# 9     -0.033471 -0.225260
# 10    -0.493782 -1.239101
# 11     1.697993  1.995605
# 12    -0.368368 -0.236594
# 13    -0.593150 -1.186786
# 14     2.449662  4.207404
# 15     3.049309  8.376643
# 16    -0.516653 -1.431953
# 17    -0.697035 -1.180393
# 18     0.147970  0.786398
# 19     0.107622  0.284780
# 20    -0.549666 -1.026068
# 21     0.172748 -0.323419
# 22     0.305751 -0.031710
# 23     0.956137  1.987200
# 24     0.603920  0.654178
# 25    -0.878833 -1.524241
# 26    -0.777316 -1.437724
# 27     0.286270  0.865279
# 28     0.221638  0.109037
# 29    -0.782120 -1.320600
# ...         ...       ...
# 19970 -0.878833 -1.569772
# 19971 -0.259589 -0.362584
# 19972  1.629563  2.831281
# 19973 -0.494578 -0.614319
# 19974 -0.455575 -0.792036
# 19975 -0.492583 -0.766532
# 19976 -0.878833 -1.492550
# 19977 -0.125879 -0.561196
# 19978  0.624033  0.785576
# 19979 -0.199721 -0.151205
# 19980 -0.878833 -1.528097
# 19981 -0.612387 -1.181525
# 19982 -0.878833 -1.573437
# 19983 -0.088103  0.089823
# 19984  1.769794  3.440178
# 19985  0.103886 -0.156918
# 19986 -0.558179 -0.813768
# 19987 -0.675577 -1.129062
# 19988 -0.667972 -0.949920
# 19989 -0.532825 -0.937561
# 19990 -0.696500 -1.311839
# 19991 -0.245172 -0.413407
# 19992 -0.361265 -0.470796
# 19993 -0.557347 -1.155647
# 19994 -0.787353 -1.296606
# 19995 -0.373728 -0.616290
# 19996  0.998291  1.159329
# 19997 -0.878833 -1.606851
# 19998 -0.878833 -1.489538
# 19999 -0.505130 -1.130279
#
# [20000 rows x 9 columns]

# %%
pred = test_df.apply(lambda x: x.jaccard >= sorted(j_list.loc[x.userID])[len(j_list.loc[x.userID])//2], axis = 1)

# %%
test_df['pred'] = pred

# %%
sum(pred == new_val.read)/len(pred)
# Out:
# 0.6417

# %%
test_df = pd.DataFrame({'userID':[], 'bookID':[]})
count = 0
for l in open("pairs_Read.txt"):
    if l.startswith("userID"):
        continue
    u,b = l.strip().split('-')
    test_df = test_df.append({'userID': u , 'bookID': b} , ignore_index=True)

# %%
test_df.groupby('userID')['bookID'].apply(list)
# Out:
# userID
# u00013729                               [b30189933, b65050854]
# u00015033                               [b65310214, b75687427]
# u00045712                               [b10451434, b97330601]
# u00066827                               [b35841877, b18393772]
# u00068766                               [b99899820, b46363613]
# u00072947                               [b08606376, b79048149]
# u00087472         [b18741581, b62734207, b71027077, b37028746]
# u00098349    [b61418655, b96403431, b48178542, b87040093, b...
# u00100195                               [b33483708, b38208557]
# u00119080         [b63964479, b57458967, b86137861, b74344779]
# u00129022                               [b40464871, b84230046]
# u00141989                               [b10586979, b27525165]
# u00151341         [b13058481, b22366895, b47086160, b32207996]
# u00169633                               [b50180436, b16744002]
# u00181613    [b75377845, b03439601, b14213635, b86041841, b...
# u00229956                               [b02416846, b78274584]
# u00236745                               [b76583092, b15569831]
# u00243120    [b24890376, b72277506, b28953246, b33737897, b...
# u00245273                               [b14541869, b22145476]
# u00265875                               [b86689267, b16499800]
# u00270072    [b00161200, b50240861, b67994054, b16078520, b...
# u00273482                               [b68077231, b26730655]
# u00285180                               [b43245219, b35285638]
# u00331735         [b88341668, b55315814, b79408250, b55738253]
# u00346928                               [b42942876, b09236808]
# u00379806                               [b08817066, b34682109]
# u00389709                               [b59738316, b74175489]
# u00404336                               [b70895515, b56324433]
# u00405736    [b00387796, b75615395, b15926648, b89126603, b...
# u00411402                               [b13598775, b35736761]
#                                    ...
# u99538438                               [b23226537, b46263957]
# u99595458                               [b73515665, b36171979]
# u99599404                               [b57873410, b14943792]
# u99601122                               [b87857983, b42593799]
# u99610740                               [b15331495, b97679256]
# u99636763         [b07235862, b26569716, b23572471, b62144682]
# u99645239                               [b02293155, b04409940]
# u99646953                               [b75196649, b62909779]
# u99658133    [b39078899, b81167384, b03586215, b04440313, b...
# u99691379                               [b82711911, b33082978]
# u99706940    [b84171017, b39335765, b25743976, b79532542, b...
# u99721383                               [b02942793, b22593148]
# u99754170                               [b90992314, b43794890]
# u99759913         [b39270822, b24168787, b01425053, b06202654]
# u99769414         [b96317640, b21180137, b03945041, b27771696]
# u99789089                               [b20253956, b20094822]
# u99793998         [b05710346, b67262410, b45584044, b40748733]
# u99798378                               [b16968708, b38579944]
# u99811566                               [b33729502, b95461580]
# u99820246                               [b24717503, b46323115]
# u99822080                               [b71318537, b07546945]
# u99831222         [b68521003, b14251150, b36620277, b00018394]
# u99864337         [b21622024, b91412409, b71630311, b19760133]
# u99875486                               [b02766219, b60295822]
# u99884530                               [b27563812, b81698526]
# u99886892                               [b17561585, b26273966]
# u99929916                               [b55725793, b47696618]
# u99931231         [b97771262, b09673761, b94349488, b25926911]
# u99941717                               [b47086160, b49721126]
# u99970798                               [b93064065, b86011795]
# Name: bookID, Length: 6349, dtype: object

# %%
predictions = open("predictions_Read.txt", 'w')
count = 0
for l in open("pairs_Read.txt"):
    if l.startswith("userID"):
        #header
        predictions.write(l)
        continue
    u,b = l.strip().split('-')
    if test_df[(test_df.userID == u) & (test_df.bookID == b)]['pred'].values[0]:
        predictions.write(u + '-' + b + ",1\n")
    else:
        predictions.write(u + '-' + b + ",0\n")
    count+=1

predictions.close()

# %% [markdown]
# Kaggle username: winniecyc
